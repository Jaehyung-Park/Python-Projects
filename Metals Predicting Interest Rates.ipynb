# %%
import pylab
import pandas as pd
import quandl
import seaborn as sns
import statsmodels as sm
token = "s5Yvqht38_gBs-ASWr9V"

# %%
df = pd.DataFrame ()
df['Yield']=quandl.get("FRED/DGS10").Value
df['Copper']=quandl.get("CHRIS/CME_HG1", authtoken=token).Settle
df['Gold']=quandl.get("CHRIS/CME_GC1", authtoken=token).Settle

# %%
df.pct_change().corr()
# Out:
#            Yield    Copper      Gold
# Yield   1.000000  0.104704 -0.054934
# Copper  0.104704  1.000000  0.290806
# Gold   -0.054934  0.290806  1.000000

# %%
sns.clustermap(df.pct_change().corr())

# %%
df.dropna().pct_change().cumsum().plot()
